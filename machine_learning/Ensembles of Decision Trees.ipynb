# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import mglearn

# %% [markdown]
# ## Random Forest

# %%
# dividindo conjunto de dados em treinamento e teste
X, y = make_moons(n_samples=100, noise=0.25, random_state=3)

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y,random_state=42)

# %%
# treinamento 

forest = RandomForestClassifier(n_estimators=5, random_state=2)
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=None,
#             oob_score=False, random_state=2, verbose=0, warm_start=False)

# %%
fig, axes = plt.subplots(2,3,figsize=(20,10))

for i, (ax, tree) in enumerate(zip(axes.ravel(), forest.estimators_)):
    ax.set_title("Árvore {}".format(i))
    mglearn.plots.plot_tree_partition(X_train, y_train, tree, ax=ax)
    
mglearn.plots.plot_2d_separator(forest, X_train, fill=True, ax=axes[-1, -1], alpha=.4)

axes[-1, -1].set_title("Random Forest")
mglearn.discrete_scatter(X_train[:, 0], X_train[:, 1], y_train)
# Out:
# [<matplotlib.lines.Line2D at 0x7f41ed8f45c0>,
#  <matplotlib.lines.Line2D at 0x7f41ed8ff470>]

# %%
print("Accuracy on training set: {:.3f}".format(forest.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(forest.score(X_test, y_test)))
# Out:
# Accuracy on training set: 0.960
# Accuracy on test set: 0.920

# %%
from sklearn.datasets import load_breast_cancer
cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, random_state=0)

forest_1 = RandomForestClassifier(n_estimators = 100, random_state=0)
forest_1.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
print("Accuracy on training set: {:.3f}".format(forest_1.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(forest_1.score(X_test, y_test)))
# Out:
# Accuracy on training set: 1.000
# Accuracy on test set: 0.972

# %%
#import matplotlib.pyplot as plt
import numpy as np
def plot_feature_importance_cancer(model):
    n_features = cancer.data.shape[1]
    plt.bar(range(n_features),model.feature_importances_, align='center')
    plt.xticks(np.arange(n_features),cancer.feature_names,rotation='vertical')
    plt.xlabel("Feature importance")
    plt.ylabel("Feature")

# %%
plot_feature_importance_cancer(forest_1)

# %% [markdown]
# ## Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, random_state=0)

# %%
gbrt = GradientBoostingClassifier(random_state=0)

# %%
gbrt.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=0,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)

# %%
print("Accuracy on training set: {:.3f}".format(gbrt.score(X_train, y_train)))
print("Accuracy on training set: {:.3f}".format(gbrt.score(X_test, y_test)))
# Out:
# Accuracy on training set: 1.000
# Accuracy on training set: 0.958

# %% [markdown]
# ## max_depth = 1

# %%
gbrt = GradientBoostingClassifier(random_state=0, max_depth=1)

# %%
gbrt.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=1,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=0,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)

# %%
print("Accuracy on training set: {:.3f}".format(gbrt.score(X_train, y_train)))
print("Accuracy on training set: {:.3f}".format(gbrt.score(X_test, y_test)))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-25-7872537fcc3f> in <module>
# ----> 1 print("Accuracy on training set: {:.3f}".format(gbrt.score(X_train, y_train)))
#       2 print("Accuracy on training set: {:.3f}".format(gbrt.score(X_test, y_test)))
#
# ~/anaconda3/envs/events/lib/python3.6/site-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     286         """
#     287         from .metrics import accuracy_score
# --> 288         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     289
#     290
#
# ~/anaconda3/envs/events/lib/python3.6/site-packages/sklearn/ensemble/gradient_boosting.py in predict(self, X)
#    2035             The predicted values.
#    2036         """
# -> 2037         score = self.decision_function(X)
#    2038         decisions = self.loss_._score_to_decision(score)
#    2039         return self.classes_.take(decisions, axis=0)
#
# ~/anaconda3/envs/events/lib/python3.6/site-packages/sklearn/ensemble/gradient_boosting.py in decision_function(self, X)
#    1990         """
#    1991         X = check_array(X, dtype=DTYPE, order="C",  accept_sparse='csr')
# -> 1992         score = self._decision_function(X)
#    1993         if score.shape[1] == 1:
#    1994             return score.ravel()
#
# ~/anaconda3/envs/events/lib/python3.6/site-packages/sklearn/ensemble/gradient_boosting.py in _decision_function(self, X)
#    1584         # for use in inner loop, not raveling the output in single-class case,
#    1585         # not doing input validation.
# -> 1586         score = self._init_decision_function(X)
#    1587         predict_stages(self.estimators_, X, self.learning_rate, score)
#    1588         return score
#
# ~/anaconda3/envs/events/lib/python3.6/site-packages/sklearn/ensemble/gradient_boosting.py in _init_decision_function(self, X)
#    1573     def _init_decision_function(self, X):
#    1574         """Check input and compute prediction of ``init``. """
# -> 1575         self._check_initialized()
#    1576         X = self.estimators_[0, 0]._validate_X_predict(X, check_input=True)
#    1577         if X.shape[1] != self.n_features_:
#
# ~/anaconda3/envs/events/lib/python3.6/site-packages/sklearn/ensemble/gradient_boosting.py in _check_initialized(self)
#    1345     def _check_initialized(self):
#    1346         """Check that the estimator is initialized, raising an error if not."""
# -> 1347         check_is_fitted(self, 'estimators_')
#    1348
#    1349     @property
#
# ~/anaconda3/envs/events/lib/python3.6/site-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     949
#     950     if not all_or_any([hasattr(estimator, attr) for attr in attributes]):
# --> 951         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     952
#     953
#
# NotFittedError: This GradientBoostingClassifier instance is not fitted yet. Call 'fit' with appropriate arguments before using this method.

# %% [markdown]
# ## learning_rate = 0.01

# %%
gbrt = GradientBoostingClassifier(random_state=0, max_depth=1, learning_rate=0.01)

# %%
gbrt.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.01, loss='deviance', max_depth=1,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=0,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)

# %%
print("Accuracy on training set: {:.3f}".format(gbrt.score(X_train, y_train)))
print("Accuracy on training set: {:.3f}".format(gbrt.score(X_test, y_test)))
# Out:
# Accuracy on training set: 0.927
# Accuracy on training set: 0.958
